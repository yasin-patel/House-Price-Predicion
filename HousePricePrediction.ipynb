# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\yasinml\ParisHousing.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8124\663773900.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df=pd.read_csv("D:\\yasinml\ParisHousing.csv")
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# ...

# %%
df.isnull().sum()
# Out:
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 17)

# %%
df.dtypes
# Out:
# squareMeters           int64
# numberOfRooms          int64
# hasYard                int64
# hasPool                int64
# floors                 int64
# cityCode               int64
# cityPartRange          int64
# numPrevOwners          int64
# made                   int64
# isNewBuilt             int64
# hasStormProtector      int64
# basement               int64
# attic                  int64
# garage                 int64
# hasStorageRoom         int64
# hasGuestRoom           int64
# price                float64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['squareMeters','numberOfRooms','hasYard','hasPool','floors','cityCode','cityPartRange','numPrevOwners','made','isNewBuilt','hasStormProtector','basement','attic','garage','hasStorageRoom','hasGuestRoom']]
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=43)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
hpricepredict=pd.DataFrame({"actual_y":y_test.values,"predicted_y":y_pred})
hpricepredict.head(10)
# Out:
#     actual_y   predicted_y
# 0  9026845.1  9.026784e+06
# 1   229172.0  2.295593e+05
# 2  6813175.5  6.813037e+06
# 3  2541947.3  2.543749e+06
# 4  9369720.7  9.369509e+06
# 5  8743395.8  8.742884e+06
# 6  5724484.4  5.720795e+06
# 7  2644436.2  2.643154e+06
# 8  7770618.8  7.771111e+06
# 9  3784160.6  3.782674e+06

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# Make predictions on the test set
y_pred = model.predict(x_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Display results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-Squared (R²): {r2}")
# Out:
# Mean Absolute Error (MAE): 1465.087374499145
# R-Squared (R²): 0.9999995691361283

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Step 4: Train the Model
rf_model.fit(x_train, y_train)

# Step 5: Make Predictions
y_pred_rf = rf_model.predict(x_test)

# Step 6: Evaluate the Model
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f'Random Forest Regression - Mean Squared Error: {mse_rf}')
print(f'Random Forest Regression - R^2 Score: {r2_rf}')
# Out:
# Random Forest Regression - Mean Squared Error: 15685507.323550308
# Random Forest Regression - R^2 Score: 0.9999981002984001

# %%
import pickle as pkl

# %%
with open('rf_model.pkl', 'wb') as f:
    pkl.dump(rf_model, f)
